# %% [markdown]
# <a href="https://colab.research.google.com/github/angelomaia/alura-cursos/blob/master/Forma%C3%A7%C3%A3o%20Deep%20Learning%20com%20Pytorch/Otimiza%C3%A7%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
from torch import nn

# %%
from sklearn import datasets

wine = datasets.load_wine()

# %%
features = [0,9]
data = wine.data[:,features]
targets = wine.target

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(data[:,0], data[:,1], c=targets, cmap=plt.cm.brg)
plt.xlabel(wine.feature_names[features[0]])
plt.ylabel(wine.feature_names[features[1]])
# Out:
# Text(0, 0.5, 'color_intensity')

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
data = scaler.fit_transform(data)

# %%
plt.scatter(data[:,0], data[:,1], c=targets, cmap=plt.cm.brg)
plt.xlabel(wine.feature_names[features[0]])
plt.ylabel(wine.feature_names[features[1]])
# Out:
# Text(0, 0.5, 'color_intensity')

# %%
if torch.cuda.is_available():
  device = torch.device('cuda')
else:
  device = torch.device('cpu')

print (device)
# Out:
# cuda

# %%
input_size = data.shape[1]
hidden_size = 32
out_size = len(wine.target_names)

net = nn.Sequential(
    nn.Linear(input_size, hidden_size),
    nn.ReLU(),
    nn.Linear(hidden_size, out_size),
    nn.Softmax()
)

net = net.to(device)
