# %% [markdown]
# <a href="https://colab.research.google.com/github/angelomaia/alura-cursos/blob/master/Forma%C3%A7%C3%A3o%20Estat%C3%ADstica%20com%20Python%20/Data_Science-Testes_Estat%C3%ADsticos/Testes_estat%C3%ADsticos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
tmdb = pd.read_csv('https://raw.githubusercontent.com/angelomaia/alura-cursos/master/Forma%C3%A7%C3%A3o%20Estat%C3%ADstica%20com%20Python/Data_Science-Testes_Estat%C3%ADsticos/tmdb_5000_movies.csv')

# %%
tmdb.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
tmdb.describe()
# Out:
#              budget             id   popularity       revenue      runtime  \
# count  4.803000e+03    4803.000000  4803.000000  4.803000e+03  4801.000000
# mean   2.904504e+07   57165.484281    21.492301  8.226064e+07   106.875859
# std    4.072239e+07   88694.614033    31.816650  1.628571e+08    22.611935
# min    0.000000e+00       5.000000     0.000000  0.000000e+00     0.000000
# 25%    7.900000e+05    9014.500000     4.668070  0.000000e+00    94.000000
# 50%    1.500000e+07   14629.000000    12.921594  1.917000e+07   103.000000
# 75%    4.000000e+07   58610.500000    28.313505  9.291719e+07   118.000000
# max    3.800000e+08  459488.000000   875.581305  2.787965e+09   338.000000
#
#        vote_average    vote_count
# count   4803.000000   4803.000000
# mean       6.092172    690.217989
# std        1.194612   1234.585891
# min        0.000000      0.000000
# 25%        5.600000     54.000000
# 50%        6.200000    235.000000
# 75%        6.800000    737.000000
# ...

# %%
import seaborn as sns

ax = sns.histplot(tmdb.vote_average)
ax.set(xlabel='Nota média', ylabel='Votos')
ax.set_title('Votos em filmes do TMDB 5000')
# Out:
# Text(0.5, 1.0, 'Votos em filmes do TMDB 5000')

# %%
import seaborn as sns

ax = sns.histplot(tmdb.vote_average)
ax.set(xlabel='Nota média', ylabel='Frequência')
ax.set_title('Votos em filmes do TMDB 5000')
# Out:
# Text(0.5, 1.0, 'Votos em filmes do TMDB 5000')

# %%
ax = sns.boxplot(x=tmdb.vote_average)
ax.set(xlabel = 'Nota média')
ax.set_title('Distribuição das notas de filmes no TMDB 5000')
# Out:
# Text(0.5, 1.0, 'Distribuição das notas de filmes no TMDB 5000')

# %%
tmdb.query('vote_average == 0').head(3)
# Out:
#       budget                                             genres  \
# 1464       0  [{"id": 18, "name": "Drama"}, {"id": 80, "name...
# 3669       0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 3670       0                  [{"id": 10751, "name": "Family"}]
#
#                            homepage      id keywords original_language  \
# 1464                            NaN  310706       []                en
# 3669  http://www.romeothemovie.com/  113406       []                en
# 3670                            NaN  447027       []                en
#
#             original_title                                           overview  \
# 1464   Black Water Transit  In this action thriller set in post-Katrina Ne...
# 3669  Should've Been Romeo  A self-centered, middle-aged pitchman for a po...
# 3670       Running Forever  After being estranged since her mother's death...
#
#       popularity                             production_companies  \
# ...

# %%
tmdb.query('vote_average == 0 and vote_count > 0')
# Out:
#       budget genres homepage      id keywords original_language  \
# 4400       0     []      NaN  219716       []                en
#
#      original_title                                           overview  \
# 4400       Sparkler  Melba is a Californian trailer-park girl who i...
#
#       popularity production_companies production_countries release_date  \
# 4400    0.547654                   []                   []   1999-03-19
#
#       revenue  runtime spoken_languages    status tagline     title  \
# 4400        0     96.0               []  Released     NaN  Sparkler
#
#       vote_average  vote_count
# 4400           0.0           1

# %%
tmdb_com_mais_de_10_votos = tmdb.query('vote_count >= 10')

ax = sns.boxplot(x=tmdb_com_mais_de_10_votos.vote_average)
ax.set(xlabel = 'Nota média')
ax.set_title('Distribuição das notas de filmes no TMDB 5000')
# Out:
# Text(0.5, 1.0, 'Distribuição das notas de filmes no TMDB 5000')

# %%
tmdb_com_mais_de_10_votos.shape
# Out:
# (4392, 20)

# %%
ax = sns.histplot(tmdb_com_mais_de_10_votos.vote_average, kde=True)
ax.set(xlabel='Nota média', ylabel='Frequência')
ax.set_title('Notas médias de filmes do TMDB 5000 com pelo menos 10 votos')
# Out:
# Text(0.5, 1.0, 'Notas médias de filmes do TMDB 5000 com pelo menos 10 votos')

# %%
ax = sns.boxplot(x=tmdb_com_mais_de_10_votos.vote_average)
ax.set(xlabel='Nota média', ylabel='Frequência')
ax.set_title('Notas médias de filmes do TMDB 5000 com pelo menos 10 votos')
# Out:
# Text(0.5, 1.0, 'Notas médias de filmes do TMDB 5000 com pelo menos 10 votos')

# %%
notas = pd.read_csv('https://raw.githubusercontent.com/angelomaia/alura-cursos/master/Forma%C3%A7%C3%A3o%20Estat%C3%ADstica%20com%20Python/Data_Science-Testes_Estat%C3%ADsticos/ratings.csv')
notas.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
nota_media_por_filme = notas.groupby('movieId').mean()['rating']

nota_media_por_filme.head()
# Out:
# movieId
# 1    3.920930
# 2    3.431818
# 3    3.259615
# 4    2.357143
# 5    3.071429
# Name: rating, dtype: float64

# %%
ax = sns.histplot(nota_media_por_filme.values, kde=True)
ax.set(xlabel='Nota média', ylabel='Frequência')
ax.set_title('Notas médias de filmes do Movielens 100k')
# Out:
# Text(0.5, 1.0, 'Notas médias de filmes do Movielens 100k')

# %%
quantidade_de_votas_por_filme = notas.groupby('movieId').count()
filmes_com_pelo_menos_10_votos = quantidade_de_votas_por_filme.query('rating >= 10').index

# %%
nota_media_dos_filmes_com_pelo_menos_10_votos = nota_media_por_filme.loc[filmes_com_pelo_menos_10_votos]
nota_media_dos_filmes_com_pelo_menos_10_votos.head()
# Out:
# movieId
# 1    3.920930
# 2    3.431818
# 3    3.259615
# 5    3.071429
# 6    3.946078
# Name: rating, dtype: float64

# %%
ax = sns.histplot(nota_media_dos_filmes_com_pelo_menos_10_votos.values, kde=True)
ax.set(xlabel='Nota média', ylabel='Frequência')
ax.set_title('Notas médias de filmes do Movielens 100k')
# Out:
# Text(0.5, 1.0, 'Notas médias de filmes do Movielens 100k')

# %%
ax = sns.boxplot(nota_media_dos_filmes_com_pelo_menos_10_votos.values)
ax.set(xlabel='Nota média', ylabel='Frequência')
ax.set_title('Notas médias de filmes do Movielens 100k')
# Out:
# Text(0.5, 1.0, 'Notas médias de filmes do Movielens 100k')

# %%
ax = sns.histplot(nota_media_dos_filmes_com_pelo_menos_10_votos.values,
                  kde=True,
                  cumulative=True)
ax.set(xlabel='Nota média', ylabel='Frequência')
ax.set_title('Notas médias de filmes do Movielens 100k')
# Out:
# Text(0.5, 1.0, 'Notas médias de filmes do Movielens 100k')
